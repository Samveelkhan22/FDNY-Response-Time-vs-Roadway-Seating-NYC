# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import pandas as pd
import re
import plotly.express as px

# %% [markdown]
# # Loading Datasets

# %%
# Load FDNY Monthly Response Times dataset
fdny_df = pd.read_csv("FDNY_Monthly_Response_Times_20250304.csv")

# Load Open Restaurant Applications dataset
restaurant_df = pd.read_csv("Open_Restaurant_Applications__Historic__20250304.csv")

# %% [markdown]
# # Datasets Exploration

# %%
print(fdny_df.head())
print(restaurant_df.head())
# Out:
#   YEARMONTH        INCIDENTCLASSIFICATION INCIDENTBOROUGH  INCIDENTCOUNT  \
# 0   2009/07  All Fire/Emergency Incidents        Citywide          40850
# 1   2009/07  All Fire/Emergency Incidents       Manhattan          10709
# 2   2009/07  All Fire/Emergency Incidents           Bronx           8137
# 3   2009/07  All Fire/Emergency Incidents   Staten Island           2205
# 4   2009/07  All Fire/Emergency Incidents        Brooklyn          11505
#
#   AVERAGERESPONSETIME
# 0               04:27
# 1               04:32
# 2               04:37
# 3               04:45
# 4               04:01
#    objectid                                globalid  \
# 0     13610  {FD87ABAA-860E-4762-845D-8F0403D0246B}
# 1      5900  {3B07E4C0-07B7-4079-8333-64446CC3EE03}
# 2     13018  {137C575D-DC14-4F9D-83D9-A3FFE513B3B8}
# 3     11630  {15270732-2A78-4C24-89DD-BE8DD916F115}
# 4     13137  {EF9C8173-91D1-496E-8BD4-B02BEADC2A21}
#
#   Seating Interest (Sidewalk/Roadway/Both)            Restaurant Name  \
# 0                                  roadway               MADAME BONTE
# 1                                 sidewalk             Seasoned Vegan
# 2                                 sidewalk  AMERICAS CAFE &amp; GRILL
# 3                                  roadway                 SUSHI SEKI
# 4                                  roadway            Sami &amp; Susu
#
#    Legal Business Name    Doing Business As (DBA) Building Number  \
# 0        BEANHOUSE LLC               MADAME BONTE             NaN
# 1  Seasoned Vegan, LLC        Seasoned Vegan, LLC              55
# 2       68TH GRILL INC  AMERICAS CAFE &amp; GRILL             NaN
# 3             SEKI INC                 SUSHI SEKI       undefined
# 4          AMIR NATHAN                Sami & Susu             NaN
#
#                  Street    Borough  Postcode  ... healthCompliance_terms  \
# 0  318 EAST   84 STREET  Manhattan     10028  ...                    yes
# 1   St. Nicholas Avenue  Manhattan     10026  ...                    yes
# 2         1159 3 AVENUE  Manhattan     10065  ...                    yes
# 3  208 WEST   23 STREET  Manhattan     10011  ...                    yes
# 4    190 ORCHARD STREET  Manhattan     10002  ...                    yes
#
#        Time of Submission   Latitude  Longitude  Community Board  \
# 0  06/09/2022 04:26:00 PM  40.776277 -73.952051              8.0
# 1  06/26/2020 08:38:00 PM  40.800500 -73.952507             10.0
# 2  10/22/2021 11:01:00 AM  40.766845 -73.962708              8.0
# 3  12/14/2020 07:54:00 PM  40.744338 -73.996240              4.0
# 4  12/22/2021 12:46:00 PM  40.722124 -73.988160              3.0
#
#    Council District  Census Tract        BIN           BBL  \
# 0               5.0         138.0  1049941.0  1.015460e+09
# 1               9.0         216.0  1054995.0  1.018220e+09
# 2               4.0         118.0  1043896.0  1.014220e+09
# 3               3.0          91.0  1014129.0  1.007720e+09
# 4               1.0        3001.0  1005393.0  1.004120e+09
#
#                                           NTA
# 0                                   Yorkville
# 1                        Central Harlem South
# 2                 Lenox Hill-Roosevelt Island
# 3  Hudson Yards-Chelsea-Flatiron-Union Square
# 4                                   Chinatown
#
# [5 rows x 35 columns]

# %%
# Display basic information about the datasets
print(fdny_df.info())
print(restaurant_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6552 entries, 0 to 6551
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   YEARMONTH               6552 non-null   object
#  1   INCIDENTCLASSIFICATION  6552 non-null   object
#  2   INCIDENTBOROUGH         6552 non-null   object
#  3   INCIDENTCOUNT           6552 non-null   int64
#  4   AVERAGERESPONSETIME     6552 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 256.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14428 entries, 0 to 14427
# Data columns (total 35 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   objectid                                  14428 non-null  int64
#  1   globalid                                  14428 non-null  object
#  2   Seating Interest (Sidewalk/Roadway/Both)  14428 non-null  object
#  3   Restaurant Name                           14427 non-null  object
#  4   Legal Business Name                       14427 non-null  object
#  5   Doing Business As (DBA)                   14416 non-null  object
#  6   Building Number                           12776 non-null  object
#  7   Street                                    14428 non-null  object
#  8   Borough                                   14428 non-null  object
#  9   Postcode                                  14428 non-null  int64
#  10  Business Address                          14428 non-null  object
#  11  Food Service Establishment Permit #       14422 non-null  object
#  12  Sidewalk Dimensions (Length)              12118 non-null  float64
#  13  Sidewalk Dimensions (Width)               12118 non-null  float64
#  14  Sidewalk Dimensions (Area)                12118 non-null  float64
#  15  Roadway Dimensions (Length)               9054 non-null   float64
#  16  Roadway Dimensions (Width)                9054 non-null   float64
#  17  Roadway Dimensions (Area)                 9054 non-null   float64
#  18  Approved for Sidewalk Seating             14428 non-null  object
#  19  Approved for Roadway Seating              14428 non-null  object
#  20  Qualify Alcohol                           14428 non-null  object
#  21  SLA Serial Number                         9448 non-null   object
#  22  SLA License Type                          9449 non-null   object
#  23  Landmark District or Building             14428 non-null  object
#  24  landmarkDistrict_terms                    2129 non-null   object
#  25  healthCompliance_terms                    14428 non-null  object
#  26  Time of Submission                        14428 non-null  object
#  27  Latitude                                  13121 non-null  float64
#  28  Longitude                                 13121 non-null  float64
#  29  Community Board                           13121 non-null  float64
#  30  Council District                          13121 non-null  float64
#  31  Census Tract                              13121 non-null  float64
#  32  BIN                                       13026 non-null  float64
#  33  BBL                                       13026 non-null  float64
#  34  NTA                                       13121 non-null  object
# dtypes: float64(13), int64(2), object(20)
# memory usage: 3.9+ MB
# None

# %% [markdown]
# # Datasets Cleaning

# %%
# Convert AVERAGERESPONSETIME from "MM:SS" to total minutes (float)
def convert_time_to_minutes(time_str):
    try:
        minutes, seconds = map(int, time_str.split(":"))
        return minutes + seconds / 60
    except:
        return None  # Handle errors

fdny_df["AVERAGERESPONSETIME"] = fdny_df["AVERAGERESPONSETIME"].apply(convert_time_to_minutes)

# Drop any rows where conversion failed (if necessary)
fdny_df.dropna(subset=["AVERAGERESPONSETIME"], inplace=True)

# Handle mixed date formats in YEARMONTH
def clean_yearmonth(value):
    value = str(value).strip()
    if "/" in value:  # Format: YYYY/MM
        return pd.to_datetime(value, format="%Y/%m", errors="coerce")
    elif "FY" in value:  # Format: FY YYYY
        year = int(value.split(" ")[1])
        return pd.to_datetime(f"{year}-01", format="%Y-%m", errors="coerce")
    else:
        return None  # If format is unexpected

fdny_df["YEARMONTH"] = fdny_df["YEARMONTH"].apply(clean_yearmonth)
fdny_df.dropna(subset=["YEARMONTH"], inplace=True)  # Drop invalid dates

# Calculate the overall average response time
overall_avg_response_time = fdny_df["AVERAGERESPONSETIME"].mean()
print(f"Overall Average Response Time: {overall_avg_response_time:.2f} minutes")
# Out:
# Overall Average Response Time: 4.59 minutes

# %% [markdown]
# # Visualizations

# %%
# ---- Plot 1: Bar Chart of Average Response Time per Borough ----
fig1 = px.bar(fdny_df.groupby("INCIDENTBOROUGH")["AVERAGERESPONSETIME"].mean().reset_index(),
              x="INCIDENTBOROUGH", y="AVERAGERESPONSETIME",
              title="Average Response Time by Borough",
              labels={"AVERAGERESPONSETIME": "Avg Response Time (minutes)", "INCIDENTBOROUGH": "Borough"},
              color="AVERAGERESPONSETIME",
              color_continuous_scale="Blues")
fig1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="98abb9a7-7d8c-49e7-b4bb-45bf6c22218c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("98abb9a7-7d8c-49e7-b4bb-45bf6c22218c")) {                    Plotly.newPlot(                        "98abb9a7-7d8c-49e7-b4bb-45bf6c22218c",                        [{"alignmentgroup":"True","hovertemplate":"Borough=%{x}\u003cbr\u003eAvg Response Time (minutes)=%{marker.color}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[4.753548534798535,4.066895604395604,4.542628205128205,4.707509157509158,4.777060439560439,4.695215201465202],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Bronx","Brooklyn","Citywide","Manhattan","Queens","Staten Island"],"xaxis":"x","y":[4.753548534798535,4.066895604395604,4.542628205128205,4.707509157509158,4.777060439560439,4.695215201465202],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"tick ...

# %%
# ---- Plot 2: Time-Series Line Chart of Response Times ----
df_time_series = fdny_df.groupby("YEARMONTH")["AVERAGERESPONSETIME"].mean().reset_index()

fig2 = px.line(df_time_series, x="YEARMONTH", y="AVERAGERESPONSETIME",
               title="Response Time Trend Over Time",
               labels={"YEARMONTH": "Year-Month", "AVERAGERESPONSETIME": "Avg Response Time (minutes)"},
               markers=True)
fig2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e7525530-66f2-419e-af90-10dcc53289ca" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e7525530-66f2-419e-af90-10dcc53289ca")) {                    Plotly.newPlot(                        "e7525530-66f2-419e-af90-10dcc53289ca",                        [{"hovertemplate":"Year-Month=%{x}\u003cbr\u003eAvg Response Time (minutes)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":["2009-07-01T00:00:00","2009-08-01T00:00:00","2009-09-01T00:00:00","2009-10-01T00:00:00","2009-11-01T00:00:00","2009-12-01T00:00:00","2010-01-01T00:00:00","2010-02-01T00:00:00","2010-03-01T00:00:00","2010-04-01T00:00:00","2010-05-01T00:00:00","2010-06-01T00:00:00","2010-07-01T00:00:00","2010-08-01T00:00:00","2010-09-01T00:00:00","2010-10-01T00:00:00","2010-11-01T00:00:00","2010-12-01T00:00:00","2011-01-01T00:00:00","2011-02-01T00:00:00","2011-03-01T00:00:00","2011-04-01T00:00:00","2011-05-01T00:00:00","2011-06-01T00:00:00","2011-07-01T00:00:00","2011-08-01T00:00:00","2011-09-01T00:00:00","2011-10-01T00:00:00","2011-11-01T00:00:00","2011-12-01T00:00:00","2012-01-01T00:00:00","2012-02-01T00:00:00","2012-03-01T00:00:00","2012-04-01T00:00:00","2012-05-01T00:00:00","2012-06-01T00:00:00","2012-07-01T00:00:00","2012-08-01T00:00:00","2012-09-01T00:00:00","2012-10-01T00:00:00","2012-11-01T00:00:00","2012-12-01T00:00:00","2013-01-01T00:00:00","2013-02-01T00:00:00","2013-03-01T00:00:00","2013-04-01T00:00:00","2013-05-01T00:00:00","2013-06-01T00:00:00","2013-07-01T00:00:00","2013-08-01T00:00:00","2013-09-01T00:00:00","2013-10-01T00:00:00","2013-11-01T00:00:00","2013-12-01T00:00:00","2014-01-01T00:00:00","2014-02-01T00:00:00","2014-03-01T00:00:00","2014-04-01T00:00:00","2014-05-01T00:00:00","2014-06-01T00:00:00","2014-07-01T00:00:00","2014-08-01T00:00:00","2014-09-01T00:00:00","2014-10-01T00:00:00","2014-11-01T00:00:00","2014-12-01T00:00:00","2015-01-01T00:00:00","2015-02-01T00:00:00","2015-03-01T00:00:00","2015-04-01T00:00:00","2015-05-01T00:00:00","2015-06-01T00:00:00","2015-07-01T00:00:00","2015-08-01T00:00:00","2015-09-01T00:00:00","2015-10-01T00:00:00","2015-11-01T00:00:00","2015-12-01T00:00:00","2016-01-01T00:00:00","2016-02-01T00:00:00","2016-03-01T00:00:00","2016-04-01T00:00:00","2016-05-01T00:00:00","2016-06-01T00:00:00","2016-07-01T00:00:00","2016-08-01T00:00:00","2016-09-01T00:00:00","2016-10-01T00:00:00","2016-11-01T00:00:00","2016-12-01T00:00:00","2017-01-01T00:00:00","2017-02-01T00:00:00","2017-03-01T00:00:00","2017-04-01T00:00:00","2017-05-01T00:00:00","2017-06-01T00:00:
"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"], ...

# %%
# ---- Visualization 6: Incident Counts by Borough & Classification ----
fig6 = px.bar(fdny_df, x="INCIDENTBOROUGH", y="INCIDENTCOUNT", color="INCIDENTCLASSIFICATION",
              title="Incident Counts by Borough and Classification",
              labels={"INCIDENTBOROUGH": "Borough", "INCIDENTCOUNT": "Total Incidents"},
              barmode="stack", color_discrete_sequence=px.colors.qualitative.Set2)
fig6.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="30cd44f3-edcd-4d6c-957a-91acbe921f2e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("30cd44f3-edcd-4d6c-957a-91acbe921f2e")) {                    Plotly.newPlot(                        "30cd44f3-edcd-4d6c-957a-91acbe921f2e",                        [{"alignmentgroup":"True","hovertemplate":"INCIDENTCLASSIFICATION=All Fire\u002fEmergency Incidents\u003cbr\u003eBorough=%{x}\u003cbr\u003eTotal Incidents=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"All Fire\u002fEmergency Incidents","marker":{"color":"rgb(102,194,165)","pattern":{"shape":""}},"name":"All Fire\u002fEmergency Incidents","offsetgroup":"All Fire\u002fEmergency Incidents","orientation":"v","showlegend":true,"textposition":"auto","x":["Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan","Bronx","Staten Island","Brooklyn","Queens","Citywide","Manhattan ...

# %%
# ---- Visualization 7: Scatter Plot of Response Time vs Incident Count ----
fig7 = px.scatter(fdny_df, x="INCIDENTCOUNT", y="AVERAGERESPONSETIME",
                  color="INCIDENTBOROUGH", size="INCIDENTCOUNT",
                  title="Response Time vs Incident Count",
                  labels={"INCIDENTCOUNT": "Incident Count", "AVERAGERESPONSETIME": "Avg Response Time (minutes)"},
                  hover_data=["INCIDENTCLASSIFICATION"])
fig7.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="df6bde56-a430-4ea0-99ec-7ea9ee0ca952" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("df6bde56-a430-4ea0-99ec-7ea9ee0ca952")) {                    Plotly.newPlot(                        "df6bde56-a430-4ea0-99ec-7ea9ee0ca952",                        [{"customdata":[["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical Emergencies"],["NonStructural Fires"],["Structural Fires"],["All Fire\u002fEmergency Incidents"],["False Alarm"],["Medical Emergencies"],["Medical False Alarm"],["NonMedical  ...

# %%
# ---- Visualization 8: Pie Chart of Incident Distribution by Borough ----
df_pie = fdny_df.groupby("INCIDENTBOROUGH")["INCIDENTCOUNT"].sum().reset_index()
fig8 = px.pie(df_pie, names="INCIDENTBOROUGH", values="INCIDENTCOUNT",
              title="Proportion of Incidents by Borough",
              color_discrete_sequence=px.colors.qualitative.Pastel)
fig8.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3fb5137e-0a8c-49db-bc4e-d1db6a2ef249" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fb5137e-0a8c-49db-bc4e-d1db6a2ef249")) {                    Plotly.newPlot(                        "3fb5137e-0a8c-49db-bc4e-d1db6a2ef249",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"INCIDENTBOROUGH=%{label}\u003cbr\u003eINCIDENTCOUNT=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Bronx","Brooklyn","Citywide","Manhattan","Queens","Staten Island"],"legendgroup":"","name":"","showlegend":true,"values":[3320364,4724480,16727496,4463028,3354060,865564],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpola ...
